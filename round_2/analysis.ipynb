# %%
pip install numpy matplotlib pandas
# Out:
# Requirement already satisfied: numpy in /opt/homebrew/lib/python3.10/site-packages (2.2.4)
# Requirement already satisfied: matplotlib in /opt/homebrew/lib/python3.10/site-packages (3.10.1)
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.10/site-packages (2.2.3)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /Users/sarthak/Library/Python/3.10/lib/python/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/sarthak/Library/Python/3.10/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/sarthak/Library/Python/3.10/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
day1 = "/Users/sarthak/Desktop/imc/round_2/round-2-island-data-bottle_2/prices_round_2_day_-1.csv"
day2 = "/Users/sarthak/Desktop/imc/round_2/round-2-island-data-bottle_2/prices_round_2_day_0.csv"
day3 = "/Users/sarthak/Desktop/imc/round_2/round-2-island-data-bottle_2/prices_round_2_day_1.csv"

# %%
day_1 = pd.read_csv(day1,delimiter=';')
day_2 = pd.read_csv(day2,delimiter=';')
day_3 = pd.read_csv(day3,delimiter=';')

# %%
final = pd.concat([day_1,day_2,day_3],axis=0)

# %%
final
# Out:
#        day  timestamp           product  bid_price_1  bid_volume_1  \
# 0       -1          0        CROISSANTS         4304           112
# 1       -1          0              JAMS         6670            66
# 2       -1          0         SQUID_INK         2005             1
# 3       -1          0    PICNIC_BASKET1        59284            20
# 4       -1          0    PICNIC_BASKET2        30606            20
# ...    ...        ...               ...          ...           ...
# 79995    1     999900              JAMS         6519           204
# 79996    1     999900  RAINFOREST_RESIN         9995            20
# 79997    1     999900         SQUID_INK         1799            20
# 79998    1     999900    PICNIC_BASKET1        58713            15
# 79999    1     999900    PICNIC_BASKET2        30100            36
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# 0              NaN           NaN          NaN           NaN         4305
# 1           6669.0         137.0          NaN           NaN         6671
# 2           2002.0          31.0          NaN           NaN         2006
# 3          59283.0          18.0          NaN           NaN        59294
# 4          30605.0          18.0          NaN           NaN        30612
# ...            ...           ...          ...           ...          ...
# 79995          NaN           NaN          NaN           NaN         6521
# 79996          NaN           NaN          NaN           NaN        10005
# 79997          NaN           NaN          NaN           NaN         1802
# 79998      58712.0          21.0          NaN           NaN        58724
# 79999          NaN           NaN          NaN           NaN        30107
#
#        ask_volume_1  ask_price_2  ask_volume_2  ask_price_3  ask_volume_3  \
# 0               112          NaN           NaN          NaN           NaN
# 1                66       6672.0         137.0          NaN           NaN
# 2                31          NaN           NaN          NaN           NaN
# 3                 2      59295.0          36.0          NaN           NaN
# 4                20      30613.0          18.0          NaN           NaN
# ...             ...          ...           ...          ...           ...
# 79995           204          NaN           NaN          NaN           NaN
# 79996            20          NaN           NaN          NaN           NaN
# 79997            20          NaN           NaN          NaN           NaN
# 79998            15      58725.0          21.0          NaN           NaN
# 79999            36          NaN           NaN          NaN           NaN
#
#        mid_price  profit_and_loss
# 0         4304.5              0.0
# 1         6670.5              0.0
# 2         2005.5              0.0
# 3        59289.0              0.0
# 4        30609.0              0.0
# ...          ...              ...
# 79995     6520.0              0.0
# 79996    10000.0              0.0
# 79997     1800.5              0.0
# 79998    58718.5              0.0
# 79999    30103.5              0.0
#
# [240000 rows x 17 columns]

# %%
croissant = final.loc[final['product'] == 'CROISSANTS']
djembes = final.loc[final['product'] == 'DJEMBES']
jams = final.loc[final['product'] == 'JAMS']
b1 = final.loc[final['product'] == 'PICNIC_BASKET1']
b2 = final.loc[final['product'] == 'PICNIC_BASKET2']

# %%
spread_cj = (jams.mid_price.values-croissant.mid_price.values)

# %%
np.mean((croissant.ask_price_1+croissant.bid_price_1)/2)
# Out:
# np.float64(4297.841033333333)

# %%
np.mean((jams.ask_price_1+jams.bid_price_1)/2)
# Out:
# np.float64(6593.315666666666)

# %%
np.std(((jams.ask_price_1+jams.bid_price_1)/2) - ((croissant.ask_price_1+croissant.bid_price_1)/2))
# Out:
# np.float64(73.66954088573392)

# %%
print(np.mean(spread_cj))
print(np.std(spread_cj))
# Out:
# 2295.4746333333333
# 40.0489170456858

# %%
plt.plot(spread_cj)

# %%
for pr1 in [croissant,djembes,jams]:
    for pr2 in [croissant,djembes,jams]:
        if pr1.product != pr2.product:
            # print(f"{pr1.product} vs {pr2.product}")
            plt.plot(pr1.mid_price.values-pr2.mid_price.values)
            plt.show()

# %%
cr1 = (croissant.mid_price.values - min(croissant.mid_price.values))/(max(croissant.mid_price.values)-min(croissant.mid_price.values))
cr2 = (djembes.mid_price.values - min(djembes.mid_price.values))/(max(djembes.mid_price.values)-min(djembes.mid_price.values))
diff = croissant.mid_price.values - djembes.mid_price.values
cr3 = (diff - min(diff))/(max(diff)-min(diff))

# %%
plt.plot(croissant.mid_price.values/djembes.mid_price.values)

# %%
plt.plot(cr1)
plt.plot(cr2)
# plt.plot(cr3,color = "purple")
plt.plot()
# Out:
# []

# %%
plt.plot(cr1/cr2)
# Out:
# /var/folders/8q/g9zgyk_93cx60fwx51810pjh0000gn/T/ipykernel_10847/631950.py:1: RuntimeWarning: divide by zero encountered in divide
#   plt.plot(cr1/cr2)

# %%
plt.plot(croissant.mid_price.values)
plt.plot(djembes.mid_price.values-9150)

# %%
b1.mid_price.values
# Out:
# array([59289. , 59287. , 59293.5, ..., 58715. , 58725.5, 58718.5],
#       shape=(30000,))

# %%
plt.plot(b1.mid_price.values/croissant.mid_price.values/6)

# %%
plt.plot(b1.mid_price.values,color="red")
plt.plot(croissant.mid_price.values,color="green")

# %%
pb_1 = 6*croissant.mid_price.values + 1*djembes.mid_price.values + 3*jams.mid_price.values 
pb_2 = 4*croissant.mid_price.values + 2*jams.mid_price.values

# %%
spread_1 = b1.mid_price.values - pb_1
plt.plot(spread_1)
print(spread_1.mean())
print(spread_1.std())
# Out:
# 48.762433333333334
# 85.1180321401536

# %%
spread_2 = b2.mid_price.values - pb_2
plt.plot(spread_2)
print(spread_2.mean())
print(spread_2.std())
# Out:
# 30.235966666666666
# 59.84820272766946

# %%
plt.plot()

# %%
y = croissant.mid_price.values
x = jams.mid_price.values

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl.metadata (31 kB)
# Requirement already satisfied: numpy>=1.19.5 in /opt/homebrew/lib/python3.10/site-packages (from scikit-learn) (2.2.4)
# Collecting scipy>=1.6.0 (from scikit-learn)
#   Downloading scipy-1.15.2-cp310-cp310-macosx_14_0_arm64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.6.1-cp310-cp310-macosx_12_0_arm64.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 20.2 MB/s eta 0:00:00 0:00:01
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.15.2-cp310-cp310-macosx_14_0_arm64.whl (22.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 10.0 MB/s eta 0:00:00a 0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
import sklearn.linear_model


model = sklearn.linear_model.LinearRegression()

# %%
x.reshape(-1,1)
# Out:
# array([[6670.5],
#        [6670.5],
#        [6671. ],
#        ...,
#        [6519.5],
#        [6520. ],
#        [6520. ]], shape=(30000, 1))

# %%
model.fit(x.reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([0.3535586])

# %%
model.intercept_
# Out:
# np.float64(1966.7175519386656)

# %%
y = final[final["product"] == "CROISSANTS"].mid_price.values
x = final[final["product"] == "DJEMBES"].mid_price.values

# %%
X = pd.Series(x)
y = pd.Series(y)

# %%
X = X.copy().to_frame()
y = y.copy()

# %%
B = np.linalg.multi_dot([np.linalg.inv(np.dot(X.transpose(),X)), X.transpose(), y])

# %%
djembes.mid_price.mean()
# Out:
# np.float64(13436.230966666666)

# %%
B
# Out:
# array([0.31987103])

# %%
# y = b*x
# b = 0.65182388
# y is croissant price
# x is jams price
