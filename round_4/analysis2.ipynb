# %%
pip install pandas numpy scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
d3 = pd.read_csv("/Users/sarthak/Desktop/imc/round_4/merge_3.csv",delimiter=";")
d2 = pd.read_csv("/Users/sarthak/Desktop/imc/round_4/merge_2.csv",delimiter=";")
d1 = pd.read_csv("/Users/sarthak/Desktop/imc/round_4/merge_1.csv",delimiter=";")

# %%
d1
# Out:
#         timestamp  bidPrice  askPrice  transportFees  exportTariff  \
# 0               0     627.0     628.5            1.0           9.0
# 1               0     627.0     628.5            1.0           9.0
# 2               0     627.0     628.5            1.0           9.0
# 3               0     627.0     628.5            1.0           9.0
# 4               0     627.0     628.5            1.0           9.0
# ...           ...       ...       ...            ...           ...
# 149995     999900     658.0     659.5            1.4          10.5
# 149996     999900     658.0     659.5            1.4          10.5
# 149997     999900     658.0     659.5            1.4          10.5
# 149998     999900     658.0     659.5            1.4          10.5
# 149999     999900     658.0     659.5            1.4          10.5
#
#         importTariff  sugarPrice  sunlightIndex  day  \
# 0               -3.0    200.0000          60.00    1
# ...

# %%
macron = d3.loc[d3['product'] == 'MAGNIFICENT_MACARONS']
macron.head()
# Out:
#     timestamp  bidPrice  askPrice  transportFees  exportTariff  importTariff  \
# 4           0     671.0     672.5            2.1          10.0          -3.0
# 19        100     672.0     673.5            2.1          10.0          -3.0
# 34        200     668.5     670.0            2.1          10.0          -3.0
# 49        300     668.5     670.0            2.1          10.0          -3.0
# 64        400     668.0     669.5            2.1          10.0          -3.0
#
#     sugarPrice  sunlightIndex  day               product  ...  bid_price_3  \
# 4   199.000000          55.00    3  MAGNIFICENT_MACARONS  ...        658.0
# 19  199.064089          55.00    3  MAGNIFICENT_MACARONS  ...        659.0
# 34  198.783168          55.01    3  MAGNIFICENT_MACARONS  ...        656.0
# 49  198.545120          55.02    3  MAGNIFICENT_MACARONS  ...        656.0
# 64  198.455261          55.02    3  MAGNIFICENT_MACARONS  ...        655.0
#
# ...

# %%
macron.columns
# Out:
# Index(['timestamp', 'bidPrice', 'askPrice', 'transportFees', 'exportTariff',
#        'importTariff', 'sugarPrice', 'sunlightIndex', 'day', 'product',
#        'bid_price_1', 'bid_volume_1', 'bid_price_2', 'bid_volume_2',
#        'bid_price_3', 'bid_volume_3', 'ask_price_1', 'ask_volume_1',
#        'ask_price_2', 'ask_volume_2', 'ask_price_3', 'ask_volume_3',
#        'mid_price', 'profit_and_loss'],
#       dtype='object')

# %%
X = macron[['sugarPrice', 'sunlightIndex']]
y = macron['mid_price']

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
# model = RandomForestRegressor()
model = LinearRegression(fit_intercept=True)
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test, y_test)
# Out:
# 0.8195408937171113

# %%
model.coef_
# Out:
# array([ 3.3511595 , -2.82607896])

# %%
np.correlate()
# Out:
# array([9.51820803e+12])
